# %% [markdown]
# # IC Data Consistency Checks

# %% [markdown]
# ## This notebook contains the following topics
# ### 01. Importing Libraries and Data
# ### 02. Data Consistency Checks for products.csv
# ##### a) Mixed Type Data
# ##### b) Missing Values
# ##### c) Duplicates
# ### 03. Data Consistency Checks for wrangled_orders.csv

# %% [markdown]
# # 01. Importing Libraries and Data

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create folder path
path = r'C:\Users\ezrela\Documents\CareerFoundry\DD-MM-2020 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\ezrela\\Documents\\CareerFoundry\\DD-MM-2020 Instacart Basket Analysis'

# %%
# Import products.csv as df_prods
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# Import orders_wrangled.csv as df_ords
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %% [markdown]
# # 02. Data Consistency Checks for products.csv

# %% [markdown]
# ## Mixed Type Data

# %%
# Create a dataframe
df_test = pd.DataFrame()

# %%
# Create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %%
# Correcting mixed data type by changing all data to string
df_test['mix'] = df_test['mix'].astype

# %%
# Check for mixed types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)

# %% [markdown]
# ## Missing Values

# %%
# Finding missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# Creating a subset of missing values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# Shape of original dataframe
df_prods.shape
# Out:
# (49693, 5)

# %%
# Dropping the column with missing values by creating a subset without the missing values
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
# Shape of dataframe after dropping the missing values
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# ##  Duplicates

# %%
# Finding duplicates
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# Addressing duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
# Exporting df_prods_clean_no_dups
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # 03. Data Consistency Checks for wrangled_orders.csv

# %% [markdown]
# ### Run the df.describe() function on your df_ords dataframe. Using your new knowledge about how to interpret the output of this function, share in a markdown cell whether anything about the data looks off or should be investigated further.

# %%
# Getting the descriptive analysis of wrangled_orders.csv file
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        order_day_of_week  order_hour_of_day  days_since_prior_order
# count       3.421083e+06       3.421083e+06            3.214874e+06
# mean        2.776219e+00       1.345202e+01            1.111484e+01
# std         2.046829e+00       4.226088e+00            9.206737e+00
# min         0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# ##### Nothing about the data looks off or unusual. The columns of particular interest are the order_day_of_week, order_hour_of_day, and days_since_prior_order. The recorded numbers fall within the range of expected numbers (7 days in a week, 24 hours in a day)

# %% [markdown]
# ### Check for mixed-type data in your df_ords dataframe.

# %%
# Checking for mixed-type data
for col in df_ords.columns.tolist():
    weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1) 
    if len (df_ords[weird])>0:
        print (col)

# %% [markdown]
# ##### There are no mixed data type in df_ords

# %% [markdown]
# ### Run a check for missing values in your df_ords dataframe.

# %%
#Finding missing values in df_ords
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# ##### The only column with missing values is the column 'days_since_prior_order'. The missing values could be as a result of orders from new customers who do not have prior orders.

# %%
# Creating a subset of the missing values
df_ords_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_ords_nan
# Out:
#          Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0                 0   2539329        1             1                  2
# 11               11   2168274        2             1                  2
# 26               26   1374495        3             1                  1
# 39               39   3343014        4             1                  6
# 45               45   2717275        5             1                  3
# ...             ...       ...      ...           ...                ...
# 3420930     3420930    969311   206205             1                  4
# 3420934     3420934   3189322   206206             1                  3
# 3421002     3421002   2166133   206207             1                  6
# 3421019     3421019   2227043   206208             1                  1
# 3421069     3421069   3154581   206209             1                  3
#
#          order_hour_of_day  days_since_prior_order  new_user_order
# ...

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0                 0   2539329        1             1                  2
# 1                 1   2398795        1             2                  3
# 2                 2    473747        1             3                  3
# 3                 3   2254736        1             4                  4
# 4                 4    431534        1             5                  4
# ...             ...       ...      ...           ...                ...
# 3421078     3421078   2266710   206209            10                  5
# 3421079     3421079   1854736   206209            11                  4
# 3421080     3421080    626363   206209            12                  1
# 3421081     3421081   2977660   206209            13                  1
# 3421082     3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %% [markdown]
# ##### The tables above confirm that the missing values are a result of orders from new customers. The 'order_number' column has 1 for all the rows with 'NaN' in the 'days_since_prior_order' column, indicating that this is the first order from respective user. The rows without missing values have order_numbers above 1.

# %% [markdown]
# ### Address the missing values using an appropriate method.

# %%
# Addressing missing values in df_ords by creating a new flag variable
df_ords['new_user_order'] = df_ords['days_since_prior_order'].isnull()

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0           0   2539329        1             1                  2
# 1           1   2398795        1             2                  3
# 2           2    473747        1             3                  3
# 3           3   2254736        1             4                  4
# 4           4    431534        1             5                  4
#
#    order_hour_of_day  days_since_prior_order  new_user_order
# 0                  8                     NaN            True
# 1                  7                    15.0           False
# 2                 12                    21.0           False
# 3                  7                    29.0           False
# 4                 15                    28.0           False

# %%
df_nan
# Out:
#          Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0                 0   2539329        1             1                  2
# 11               11   2168274        2             1                  2
# 26               26   1374495        3             1                  1
# 39               39   3343014        4             1                  6
# 45               45   2717275        5             1                  3
# ...             ...       ...      ...           ...                ...
# 3420930     3420930    969311   206205             1                  4
# 3420934     3420934   3189322   206206             1                  3
# 3421002     3421002   2166133   206207             1                  6
# 3421019     3421019   2227043   206208             1                  1
# 3421069     3421069   3154581   206209             1                  3
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %% [markdown]
# ##### I think the most appropraite approach to treat the missing values is to create a new variable, 'new_user_order', indicating that the rows with missing values in the column 'days_since_prior_order' are new users. Inputting values or removing these records will significantly change the true analytical results of the data. Since a new column is being created, and can be dropped, the df_ords was overwritten, instead of creating an entirely new df.

# %% [markdown]
# ## Run a check for duplicate values in your df_ords data.

# %%
# Checking for duplicates in df_ords
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order, new_user_order]
# Index: []

# %% [markdown]
# ##### There are no duplicated rows in df_ords

# %%
df_ords.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'))

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# ##### The maximum price in the products.csv looks like a typographical error in the price column of the file. The value of the mean also shows that the maximum price is unusually high; therefore, it is an anomaly. Also, the maximum product_id may be an anomaly as the expected max product_id is 49693, based on the count. This could indicate duplicated product_id, that is, a product_id appearing more than once.
